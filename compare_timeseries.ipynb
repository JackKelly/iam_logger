# %%
import pandas
import numpy as np
from __future__ import print_function

rng = pandas.date_range('1/1/2011', periods=10, freq='H')
rng2 = pandas.date_range('1/1/2011 05:00:00', periods=10, freq='H')
ts1 = pandas.Series(2*(len(rng)), index=rng)
ts2 = pandas.Series(2*(len(rng)), index=rng2)

print(ts1)
print(ts2)
# Out:
# 2011-01-01 00:00:00    20
# 2011-01-01 01:00:00    20
# 2011-01-01 02:00:00    20
# 2011-01-01 03:00:00    20
# 2011-01-01 04:00:00    20
# 2011-01-01 05:00:00    20
# 2011-01-01 06:00:00    20
# 2011-01-01 07:00:00    20
# 2011-01-01 08:00:00    20
# 2011-01-01 09:00:00    20
# Freq: H
# 2011-01-01 05:00:00    20
# 2011-01-01 06:00:00    20
# 2011-01-01 07:00:00    20
# 2011-01-01 08:00:00    20
# 2011-01-01 09:00:00    20
# 2011-01-01 10:00:00    20
# 2011-01-01 11:00:00    20
# 2011-01-01 12:00:00    20
# 2011-01-01 13:00:00    20
# 2011-01-01 14:00:00    20
# Freq: H

# %%
def comparison(a,b):
    if np.isnan(a):
        return b
    elif np.isnan(b):
        return a
    elif a==b:
        return a
    else:
        raise Exception("oops. a={}, b={}".format(a,b))
        
combined = ts2.combine(ts1, comparison)

print(combined)
# Out:
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# c=None
# 2011-01-01 00:00:00    20
# 2011-01-01 01:00:00    20
# 2011-01-01 02:00:00    20
# 2011-01-01 03:00:00    20
# 2011-01-01 04:00:00    20
# 2011-01-01 05:00:00    20
# 2011-01-01 06:00:00    20
# 2011-01-01 07:00:00    20
# 2011-01-01 08:00:00    20
# 2011-01-01 09:00:00    20
# 2011-01-01 10:00:00    20
# 2011-01-01 11:00:00    20
# 2011-01-01 12:00:00    20
# 2011-01-01 13:00:00    20
# 2011-01-01 14:00:00    20
# Freq: H

# %%
ts1.index[1] == ts2.index[1]
# Out:
# False

# %%
path = '/home/jack/workingcopies/domesticPowerData/BellendenRd/version2/'
filename1 = path + 'channel_01.dat'
filename2 = path + 'channel_99.dat'
data1 = np.genfromtxt(filename1, usecols=[0,1], dtype=int)
data2 = np.genfromtxt(filename2, usecols=[0,1], dtype=int)
print(filename1)
print(data1)
print(filename2)
print(data2[18680])
len(data2)
# Out:
# /home/jack/workingcopies/domesticPowerData/BellendenRd/version2/channel_01.dat
# [[1343751885        263]
#  [1343751891        232]
#  [1343751897        231]
#  ...,
#  [1344021438        273]
#  [1344021451        274]
#  [1344021475        274]]
# /home/jack/workingcopies/domesticPowerData/BellendenRd/version2/channel_99.dat
# [1344026768        273]
# 18681

# %%
for row in data1:
    print(row)
    break
# Out:
# [1343751885        263]

# %%
def check_and_merge(d1, d2):
    """TODO: the assignement to the inconsistent category seems to be failing.
    """
    d2_i = 0
    merged = [] # using a list because it's faster to append to
    inconsistent = []
    slipped_sync = []
    for d1_row in d1:
        d1_timecode = d1_row[0]
        d1_reading = d1_row[1]
        new_row = [d1_timecode, d1_reading]
        
        while d2_i < len(d2):
            d2_row = d2[d2_i]
            d2_timecode = d2_row[0]
            d2_reading = d2_row[1]
            
            if d2_timecode == d1_timecode:
                if d2_reading == d1_reading:
                    print('a')
                    merged.append(new_row)
                else:
                    print('b')
                    inconsistent.append({'reason': 'b', d1_timecode: d1_reading, d2_timecode: d1_reading})
                d2_i += 1
                break
            elif d1_timecode < d2_timecode < d1_timecode+5:
                if d2_reading == d1_reading:
                    print('c')
                    slipped_sync.append([d1_timecode, d2_timecode,(d1_timecode-d2_timecode)])
                else:
                    print('d')
                    inconsistent.append({'reason': 'd', d1_timecode: d1_reading, d2_timecode: d1_reading})
                d2_i += 1
                break
            elif d1_timecode < d2_timecode:
                print('e')
                merged.append(new_row)
                break # don't increment d2_i
            elif d2_timecode < d1_timecode:
                print('f')
                merged.append([d2_timecode, d2_reading])
                d2_i += 1
                
    merged.extend(d2[d2_i:])
    
    return merged, inconsistent, slipped_sync

d1 = [[1, 10], [6, 60], [12, 120]]
d2 = [[12, 120], [18,180], [24, 240]]

m, i, s = check_and_merge(data1,data2)

print("m=\n{}\ni=\n{}\ns={}\n".format(m, i, s))
# Out:
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# ...

# %%
from array import array

arr = [array('L'), array('L')]
arr[0].append(1)
arr[1].append(2)
print(arr)
# Out:
# [array('L', [1L]), array('L', [2L])]

# %%
l1 = [1,2,3,4]
l2 = [5,6,7]

l1.extend(l2)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
